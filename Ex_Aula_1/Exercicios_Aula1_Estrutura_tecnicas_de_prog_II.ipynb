# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusRobles/Santander_Coders_Tecnicas_de_Prog_II/blob/main/Ex_Aula_1/Exercicios_Aula1_Estrutura_tecnicas_de_prog_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **EXERCICIOS AULA 1**

# %% [markdown]
# EX 1. Utilizando a plotagem com pandas, reproduzam as visualizações abaixo, tentando deixá-las o mais próximas quanto possível da maneira como estão postas. Para isso, atentem-se às personalizações dos gráficos, como títulos, legendas, eixos e outros tipos possíveis de formatações e preferências de visualizações dos dados. Também é interessante que vocês discutam possíveis pontos de melhorias dessas visualizações!
#
# Exercício 1. Reproduza o gráfico de barras abaixo, em que cada barra representa um dos 10 países com mais casos confirmados de COVID no dataset, e a "quebra" em cada cor indica a predominância de casos confirmados em cada mês.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df_covid = pd.read_csv("https://raw.githubusercontent.com/MatheusRobles/Santander_Coders_Tecnicas_de_Prog_II/main/Ex_Aula_1/Covid_19_Countrywise_timeseries.csv")

# %%
df_covid.head()
# Out:
#    Unnamed: 0 ObservationDate          country  Confirmed  Deaths  Recovered  \
# 0        1063      02/28/2020       azerbaijan          1       0          0
# 1        2055      03/10/2020  ('st. martin',)          2       0          0
# 2         869      02/24/2020      afghanistan          1       0          0
# 3         909      02/25/2020      afghanistan          1       0          0
# 4         955      02/26/2020      afghanistan          1       0          0
#
#   Code  latitude  longitude  New Confirmed  New Recovered  New Death
# 0  NaN       NaN        NaN              0              0          0
# 1  NaN       NaN        NaN              2              0          0
# 2   AF  33.93911  67.709953              1              0          0
# 3   AF  33.93911  67.709953              0              0          0
# 4   AF  33.93911  67.709953              0              0          0

# %%
df_covid['Mes'] = pd.to_datetime(df_covid['ObservationDate']).dt.strftime('%Y-%m')
df_covid
# Out:
#       Unnamed: 0 ObservationDate          country  Confirmed  Deaths  \
# 0           1063      02/28/2020       azerbaijan          1       0
# 1           2055      03/10/2020  ('st. martin',)          2       0
# 2            869      02/24/2020      afghanistan          1       0
# 3            909      02/25/2020      afghanistan          1       0
# 4            955      02/26/2020      afghanistan          1       0
# ...          ...             ...              ...        ...     ...
# 4968        4134      03/24/2020         zimbabwe          3       1
# 4969        4272      03/25/2020         zimbabwe          3       1
# 4970        4482      03/26/2020         zimbabwe          3       1
# 4971        4633      03/27/2020         zimbabwe          5       1
# 4972        4972      03/28/2020         zimbabwe          7       1
#
#       Recovered Code   latitude  longitude  New Confirmed  New Recovered  \
# ...

# %%
matriz = df_covid.groupby(["country", "Mes"])['New Confirmed'].sum().unstack().fillna(0)

# %%
matriz = matriz.sort_values('2020-03', ascending=False)[:10]
matriz.plot(kind = 'barh', stacked=True)
# Out:
# <Axes: ylabel='country'>

# %% [markdown]
# Para os exercícios abaixo, vamos trabalhar com um dataset de emissão de CO2 por país, ao longo do tempo.
#
# EX 2. Reproduza o gráfico de linhas abaixo, que representa a série temporal da evolução de emissões de CO2 no Brasil.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df_CO2 = pd.read_csv('https://raw.githubusercontent.com/MatheusRobles/Santander_Coders_Tecnicas_de_Prog_II/main/Ex_Aula_1/co2_emissions_kt_by_country.csv')
df_CO2
# Out:
#       country_code country_name  year         value
# 0              ABW        Aruba  1960  11092.675000
# 1              ABW        Aruba  1961  11576.719000
# 2              ABW        Aruba  1962  12713.489000
# 3              ABW        Aruba  1963  12178.107000
# 4              ABW        Aruba  1964  11840.743000
# ...            ...          ...   ...           ...
# 13948          ZWE     Zimbabwe  2015  12430.000305
# 13949          ZWE     Zimbabwe  2016  11020.000458
# 13950          ZWE     Zimbabwe  2017  10340.000153
# 13951          ZWE     Zimbabwe  2018  12380.000114
# 13952          ZWE     Zimbabwe  2019  11760.000229
#
# [13953 rows x 4 columns]

# %%
df_brazil_CO2 = df_CO2[df_CO2['country_name'] == 'Brazil']
df_brazil_CO2
# Out:
#      country_code country_name  year          value
# 1522          BRA       Brazil  1960   46908.264000
# 1523          BRA       Brazil  1961   49203.806000
# 1524          BRA       Brazil  1962   53695.881000
# 1525          BRA       Brazil  1963   55617.389000
# 1526          BRA       Brazil  1964   56735.824000
# 1527          BRA       Brazil  1965   56398.460000
# 1528          BRA       Brazil  1966   64304.512000
# 1529          BRA       Brazil  1967   66193.017000
# 1530          BRA       Brazil  1968   77421.371000
# 1531          BRA       Brazil  1969   84315.331000
# 1532          BRA       Brazil  1970   93761.523000
# 1533          BRA       Brazil  1971  102635.663000
# 1534          BRA       Brazil  1972  114362.729000
# 1535          BRA       Brazil  1973  132463.041000
# 1536          BRA       Brazil  1974  143456.707000
# 1537          BRA       Brazil  1975  151164.741000
# 1538          BRA       Brazil  1976  155154.437000
# ...

# %%
df_brazil_grouped = df_brazil_CO2.groupby('year')['value'].mean()
df_brazil_grouped.plot(x = df_brazil_grouped.index, y = df_brazil_grouped.values)
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# EX 3. Uma visualização muito similar à anterior, mas com a adição da média global de emissão de CO2 (o Brasil deve ser incluído na linha da média global?).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df_brazil_grouped = df_brazil_CO2.groupby('year')['value'].mean()
df_brazil_grouped.plot(x = df_brazil_grouped.index, y = df_brazil_grouped.values)

df_media_mundo_CO2 = df_CO2.groupby('year')['value'].mean()
df_media_mundo_CO2.plot(x = df_media_mundo_CO2.index, y = df_media_mundo_CO2)
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# EX 4. Os 10 países que mais aumentaram, percentualmente, a emissão de CO2 entre os anos de 2018 e 2019, na forma de um gráfico de barras horizontal.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df_2018_2019 = df_CO2[df_CO2['year'].isin([2018, 2019])]

df_total_emissions = df_2018_2019.groupby(['country_name', 'year'])['value'].sum().unstack()
df_total_emissions
# Out:
# year                                 2018          2019
# country_name
# Afghanistan                  6.070000e+03  6.080000e+03
# Africa Eastern and Southern  5.900400e+05  6.030300e+05
# Africa Western and Central   2.117200e+05  2.207400e+05
# Albania                      5.110000e+03  4.830000e+03
# Algeria                      1.655400e+05  1.712500e+05
# ...                                   ...           ...
# Vietnam                      2.856000e+05  3.364900e+05
# World                        3.428935e+07  3.434401e+07
# Yemen, Rep.                  9.720000e+03  1.110000e+04
# Zambia                       7.730000e+03  6.800000e+03
# Zimbabwe                     1.238000e+04  1.176000e+04
#
# [239 rows x 2 columns]

# %%
df_total_emissions['percent']  = ((df_total_emissions[2019] - df_total_emissions[2018]) / df_total_emissions[2018]) * 100
df_total_emissions
# Out:
# year                                 2018          2019    percent
# country_name
# Afghanistan                  6.070000e+03  6.080000e+03   0.164741
# Africa Eastern and Southern  5.900400e+05  6.030300e+05   2.201547
# Africa Western and Central   2.117200e+05  2.207400e+05   4.260344
# Albania                      5.110000e+03  4.830000e+03  -5.479456
# Algeria                      1.655400e+05  1.712500e+05   3.449322
# ...                                   ...           ...        ...
# Vietnam                      2.856000e+05  3.364900e+05  17.818622
# World                        3.428935e+07  3.434401e+07   0.159395
# Yemen, Rep.                  9.720000e+03  1.110000e+04  14.197532
# Zambia                       7.730000e+03  6.800000e+03 -12.031046
# Zimbabwe                     1.238000e+04  1.176000e+04  -5.008077
#
# [239 rows x 3 columns]

# %%
df_percent = df_total_emissions.sort_values(by='percent', ascending=False)
df_percent
# Out:
# year                        2018           2019    percent
# country_name
# Panama              10060.000420   13340.000153  32.604370
# Kenya               17489.999771   22280.000687  27.387084
# Madagascar           3349.999905    4119.999886  22.985075
# Suriname             2210.000038    2650.000095  19.909505
# Vietnam            285600.006104  336489.990234  17.818622
# ...                          ...            ...        ...
# Nepal               15189.999580   13449.999809 -11.454903
# Zambia               7730.000019    6800.000191 -12.031046
# Venezuela, RB      132130.004883  112339.996338 -14.977679
# Equatorial Guinea    6429.999828    5349.999905 -16.796267
# Estonia             15319.999695   10180.000305 -33.550911
#
# [239 rows x 3 columns]

# %%
df_percent = df_percent.head(10)
df_percent = df_percent.sort_values(by='percent', ascending=True)
df_percent
# Out:
# year                      2018           2019    percent
# country_name
# Myanmar           32939.998627   36720.001221  11.475418
# Congo, Rep.        6489.999771    7260.000229  11.864414
# North Macedonia    7300.000191    8300.000191  13.698630
# Yemen, Rep.        9720.000267   11100.000381  14.197532
# El Salvador        6809.999943    7800.000191  14.537449
# Vietnam          285600.006104  336489.990234  17.818622
# Suriname           2210.000038    2650.000095  19.909505
# Madagascar         3349.999905    4119.999886  22.985075
# Kenya             17489.999771   22280.000687  27.387084
# Panama            10060.000420   13340.000153  32.604370

# %%
ax = df_percent.head(10).percent.plot(kind = 'barh', title = "Top 10 países com maiores aumentos percentuais de emissão entre 2018 e 2019" )
ax.bar_label(ax.containers[0], fmt='%.1f%%')
# Out:
# [Text(0, 0, '11.5%'),
#  Text(0, 0, '11.9%'),
#  Text(0, 0, '13.7%'),
#  Text(0, 0, '14.2%'),
#  Text(0, 0, '14.5%'),
#  Text(0, 0, '17.8%'),
#  Text(0, 0, '19.9%'),
#  Text(0, 0, '23.0%'),
#  Text(0, 0, '27.4%'),
#  Text(0, 0, '32.6%')]
